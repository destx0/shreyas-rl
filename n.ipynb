# %%
import gymnasium as gym
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import random
from scipy import stats


def generate_demand_profile(num_steps, base_demand):
    demand_profile = np.ones(num_steps) * base_demand
    return demand_profile


def generate_solar_forecast_profile(num_steps, base_solar, solar_std, daylight_hours):
    solar_forecast_profile = np.zeros(num_steps)
    # Generate solar forecast during daylight hours
    solar_forecast_profile[daylight_hours[0] : daylight_hours[1]] = np.random.normal(
        loc=base_solar, scale=solar_std, size=daylight_hours[1] - daylight_hours[0]
    )
    return solar_forecast_profile


class ElectricityDispatchEnv(gym.Env):
    def __init__(self):
        self.action_space = gym.spaces.Box(
            low=-1, high=1, shape=(4,)
        )  # Grid, battery, generator, solar actions
        self.observation_space = gym.spaces.Box(
            low=0, high=np.inf, shape=(4,)
        )  # Demand, solar forecast, battery state, cost

        self.max_steps = 96  # 15-minute intervals for 24 hours
        self.step_count = 0

        self.demand = None
        self.solar_forecast = None
        self.battery_state = 0
        self.cost = 0
        self.num_steps = 96
        self.base_demand = 150
        self.demand_std = 30
        self.base_solar = 80
        self.solar_std = 20
        self.daylight_hours = [24, 72]
        self.grid_usage = []
        self.battery_usage = []
        self.generator_usage = []
        self.peak_hours = [36, 48, 60]
        self.grid_price_low = 0.05
        self.grid_price_high = 0.15
        self.generator_price_low = 0.08
        self.generator_price_high = 0.12
        self.battery_price_low = 0.005
        self.battery_price_high = 0.015
        self.battery_capacity = 200
        self.generator_min_output = 20
        self.generator_max_output = 100

    def reset(self):
        self.step_count = 0
        self.battery_state = 0
        self.cost = 0

        self.demand = self._generate_demand()
        self.solar_forecast = self._generate_solar_forecast()
        self.battery_state = self.battery_capacity
        self.grid_usage = []
        self.battery_usage = []
        self.generator_usage = []
        return np.array(
            [self.demand[0], self.solar_forecast[0], self.battery_state, self.cost]
        )

    def step(self, action):
        grid_action = np.clip(action[0], 0, 1)
        battery_action = np.clip(action[1], -1, 1)
        generator_action = np.clip(action[2], 0, 1)
        solar_action = np.clip(action[3], 0, 1)

        solar_supply = solar_action * self.solar_forecast[self.step_count]
        grid_supply = grid_action * (self.demand[self.step_count] - solar_supply)

        if self.battery_state < self.battery_capacity:
            battery_supply = battery_action * (
                self.battery_capacity - self.battery_state
            )
        else:
            battery_supply = 0

        generator_output = self.generator_min_output + generator_action * (
            self.generator_max_output - self.generator_min_output
        )
        generator_supply = generator_output * (
            self.demand[self.step_count] - solar_supply - grid_supply - battery_supply
        )

        # Ensure the total supply meets the demand
        total_supply = solar_supply + grid_supply + battery_supply + generator_supply
        if total_supply < self.demand[self.step_count]:
            # If total supply is less than demand, prioritize sources
            remaining_demand = self.demand[self.step_count] - total_supply
            if remaining_demand > 0:
                grid_supply += min(
                    remaining_demand,
                    self.demand[self.step_count]
                    - solar_supply
                    - battery_supply
                    - generator_supply,
                )
                remaining_demand = (
                    self.demand[self.step_count]
                    - solar_supply
                    - grid_supply
                    - battery_supply
                    - generator_supply
                )
            if remaining_demand > 0:
                generator_supply += min(
                    remaining_demand,
                    self.demand[self.step_count]
                    - solar_supply
                    - grid_supply
                    - battery_supply,
                )

        self.grid_usage.append(grid_supply)
        self.battery_usage.append(battery_supply)
        self.generator_usage.append(generator_supply)

        # Update prices based on fluctuations
        grid_price = (
            self.grid_price_high
            if self.step_count in self.peak_hours
            else self.grid_price_low
        )
        generator_price = np.random.uniform(
            self.generator_price_low, self.generator_price_high
        )
        battery_price = np.random.uniform(
            self.battery_price_low, self.battery_price_high
        )

        self.cost += (
            grid_supply * grid_price
            + generator_supply * generator_price
            + battery_supply * battery_price
        )

        reward = -self.cost  # Negative cost as reward

        # Encourage the use of renewable sources
        reward += solar_supply * 0.05
        reward += battery_supply * 0.02

        # Penalize excessive grid usage
        if grid_supply > self.demand[self.step_count] * 0.6:
            reward -= (grid_supply - self.demand[self.step_count] * 0.6) * 0.1

        # Reward for meeting the demand
        if total_supply >= self.demand[self.step_count]:
            reward += 20
        else:
            reward -= 20 * (self.demand[self.step_count] - total_supply)

        # Update battery state considering charging and discharging efficiency
        self.battery_state = np.clip(
            self.battery_state - battery_supply * (1 if battery_supply > 0 else 0.9),
            0,
            self.battery_capacity,
        )

        self.step_count += 1
        done = self.step_count >= self.max_steps

        next_state = np.array(
            [
                self.demand[self.step_count] if not done else 0,
                self.solar_forecast[self.step_count] if not done else 0,
                self.battery_state,
                self.cost,
            ]
        )

        return next_state, reward, done, {}

    def _generate_demand(self):
        demand = generate_demand_profile(self.num_steps, self.base_demand)
        demand += np.random.normal(0, self.demand_std, self.num_steps)
        return demand

    def _generate_solar_forecast(self):
        solar_forecast = generate_solar_forecast_profile(
            self.num_steps, self.base_solar, self.solar_std, self.daylight_hours
        )
        solar_forecast += np.random.normal(0, self.solar_std, self.num_steps)
        return solar_forecast


class DQN(nn.Module):
    def __init__(self, state_dim, action_dim):
        super(DQN, self).__init__()
        self.fc1 = nn.Linear(state_dim, 128)
        self.fc2 = nn.Linear(128, 128)
        self.fc3 = nn.Linear(128, action_dim)

    def forward(self, state):
        x = torch.relu(self.fc1(state))
        x = torch.relu(self.fc2(x))
        q_values = self.fc3(x)
        return q_values


class DQNAgent:
    def __init__(self, state_dim, action_dim, lr, gamma, epsilon):
        self.model = DQN(state_dim, action_dim)
        self.optimizer = optim.Adam(self.model.parameters(), lr=lr)
        self.gamma = gamma
        self.epsilon = epsilon

    def act(self, state):
        if np.random.rand() < self.epsilon:
            return np.random.uniform(-1, 1, size=4)
        state_tensor = torch.FloatTensor(state)
        q_values = self.model(state_tensor)
        action = q_values.detach().numpy()
        return action

    def train(self, state, action, reward, next_state, done):
        state_tensor = torch.FloatTensor(state)
        action_tensor = torch.FloatTensor(action)
        reward_tensor = torch.FloatTensor(reward).unsqueeze(1)
        next_state_tensor = torch.FloatTensor(next_state)
        done_tensor = torch.FloatTensor(done).unsqueeze(1)

        q_values = self.model(state_tensor)
        next_q_values = self.model(next_state_tensor)

        q_value = q_values.gather(1, action_tensor.argmax(1).unsqueeze(1))
        next_q_value, _ = next_q_values.max(1, keepdim=True)

        target = reward_tensor + (1 - done_tensor) * self.gamma * next_q_value

        loss = nn.MSELoss()(q_value, target.detach())
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()


# Create the environment
env = ElectricityDispatchEnv()

# Define the DQN agent
state_dim = env.observation_space.shape[0]
action_dim = env.action_space.shape[0]
lr = 0.001
gamma = 0.99
epsilon = 0.1
epsilon_decay = 0.995
dqn_agent = DQNAgent(state_dim, action_dim, lr, gamma, epsilon)

# Run the simulation with DQN agent
num_episodes = 2000
batch_size = 64

total_costs = []

for episode in range(num_episodes):
    state = env.reset()
    done = False
    total_reward = 0

    replay_buffer = []
    grid_prices = []
    solar_prices = []
    battery_prices = []
    generator_prices = []

    while not done:
        action = dqn_agent.act(state)
        next_state, reward, done, _ = env.step(action)
        replay_buffer.append((state, action, reward, next_state, done))

        if len(replay_buffer) > batch_size:
            batch = random.sample(replay_buffer, batch_size)
            states, actions, rewards, next_states, dones = zip(*batch)
            dqn_agent.train(states, actions, rewards, next_states, dones)

        state = next_state
        total_reward += reward

        grid_prices.extend([env.grid_price_low] * int(env.grid_usage[-1]))
        solar_prices.extend([0] * int(env.solar_forecast[-1]))
        battery_prices.extend(
            [
                (
                    env.battery_price_low
                    if env.battery_usage[-1] < 0
                    else env.battery_price_high
                )
            ]
            * int(abs(env.battery_usage[-1]))
        )
        generator_prices.extend(
            [
                env.generator_price_low
                + (env.generator_price_high - env.generator_price_low)
                * env.generator_usage[-1]
                / env.generator_max_output
            ]
            * int(env.generator_usage[-1])
        )

    epsilon *= epsilon_decay

    # Calculate total energy usage
    total_energy_usage = (
        sum(env.grid_usage)
        + sum(env.solar_forecast)
        + sum(env.battery_usage)
        + sum(env.generator_usage)
    )

    # Calculate percentage of each source
    grid_percentage = sum(env.grid_usage) / total_energy_usage * 100
    solar_percentage = sum(env.solar_forecast) / total_energy_usage * 100
    battery_percentage = sum(env.battery_usage) / total_energy_usage * 100
    generator_percentage = sum(env.generator_usage) / total_energy_usage * 100

    # Calculate energy used for charging the battery
    energy_used_for_charging = sum(usage for usage in env.battery_usage if usage < 0)

    # Calculate the mode of prices for each source
    # Calculate the mode of prices for each source
    if len(grid_prices) > 0:
        grid_price_mode = stats.mode(grid_prices, keepdims=True).mode[0]
    else:
        grid_price_mode = 0.0

    if len(solar_prices) > 0:
        solar_price_mode = stats.mode(solar_prices, keepdims=True).mode[0]
    else:
        solar_price_mode = 0.0

    if len(battery_prices) > 0:
        battery_price_mode = stats.mode(battery_prices, keepdims=True).mode[0]
    else:
        battery_price_mode = 0.0

    if len(generator_prices) > 0:
        generator_price_mode = stats.mode(generator_prices, keepdims=True).mode[0]
    else:
        generator_price_mode = 0.0

    total_cost = env.cost
    total_costs.append(total_cost)
    print(
        f"Episode {episode+1}: Total Reward = {total_reward:.2f}, Total Cost = ${total_cost:.2f}"
    )
    print(
        f"Grid Usage: {np.mean(env.grid_usage):.2f} MW ({grid_percentage:.2f}%), Mode Price = ${grid_price_mode:.2f}"
    )
    print(
        f"Solar Usage: {np.mean(env.solar_forecast):.2f} MW ({solar_percentage:.2f}%), Mode Price = ${solar_price_mode:.2f}"
    )
    print(
        f"Battery Usage: {np.mean(env.battery_usage):.2f} MW ({battery_percentage:.2f}%), Mode Price = ${battery_price_mode:.2f}"
    )
    print(
        f"Generator Usage: {np.mean(env.generator_usage):.2f} MW ({generator_percentage:.2f}%), Mode Price = ${generator_price_mode:.2f}"
    )
    print(f"Battery Capacity: {env.battery_capacity:.2f} MWh")
    print(f"Energy Used for Charging: {abs(energy_used_for_charging):.2f} MWh")
    print(f"Epsilon: {epsilon:.2f}")
    print("---")

print(f"Average Total Cost: ${np.mean(total_costs):.2f}")
# Out:
# Episode 1: Total Reward = -1314420.12, Total Cost = $27878.49
# Grid Usage: 2.75 MW (0.09%), Mode Price = $0.05
# Solar Usage: 43.84 MW (1.48%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 2906.66 MW (98.42%), Mode Price = $2.33
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.10
# ---
# Episode 2: Total Reward = -1454209.94, Total Cost = $29841.21
# Grid Usage: 5.21 MW (0.16%), Mode Price = $0.05
# Solar Usage: 41.57 MW (1.31%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3117.12 MW (98.52%), Mode Price = $4.00
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.10
# ---
# Episode 3: Total Reward = -1564264.77, Total Cost = $32094.65
# Grid Usage: 3.27 MW (0.10%), Mode Price = $0.05
# Solar Usage: 35.91 MW (1.08%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3288.76 MW (98.82%), Mode Price = $4.80
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.10
# ---
# Episode 4: Total Reward = -1460540.61, Total Cost = $29572.32
# Grid Usage: 3.18 MW (0.10%), Mode Price = $0.05
# Solar Usage: 44.29 MW (1.43%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3054.31 MW (98.47%), Mode Price = $3.92
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.10
# ---
# Episode 5: Total Reward = -1459101.41, Total Cost = $28784.20
# Grid Usage: 6.57 MW (0.21%), Mode Price = $0.05
# Solar Usage: 41.78 MW (1.33%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3096.05 MW (98.46%), Mode Price = $6.41
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.10
# ---
# Episode 6: Total Reward = -1412760.56, Total Cost = $29209.66
# Grid Usage: 2.73 MW (0.09%), Mode Price = $0.05
# Solar Usage: 44.57 MW (1.44%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3044.11 MW (98.47%), Mode Price = $3.92
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.10
# ---
# Episode 7: Total Reward = -1503294.43, Total Cost = $32940.18
# Grid Usage: 8.37 MW (0.25%), Mode Price = $0.05
# Solar Usage: 34.73 MW (1.02%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3361.05 MW (98.73%), Mode Price = $7.05
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.10
# ---
# Episode 8: Total Reward = -1393508.97, Total Cost = $28996.34
# Grid Usage: 1.23 MW (0.04%), Mode Price = $0.05
# Solar Usage: 40.81 MW (1.34%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 2999.05 MW (98.62%), Mode Price = $1.90
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.10
# ---
# Episode 9: Total Reward = -1556636.65, Total Cost = $32491.67
# Grid Usage: 2.65 MW (0.08%), Mode Price = $0.05
# Solar Usage: 42.15 MW (1.22%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3409.78 MW (98.70%), Mode Price = $4.75
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.10
# ---
# Episode 10: Total Reward = -1405182.11, Total Cost = $28964.23
# Grid Usage: 3.46 MW (0.11%), Mode Price = $0.05
# Solar Usage: 37.36 MW (1.20%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3064.05 MW (98.69%), Mode Price = $4.94
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.10
# ---
# Episode 11: Total Reward = -1388144.73, Total Cost = $28084.66
# Grid Usage: 2.45 MW (0.08%), Mode Price = $0.05
# Solar Usage: 41.06 MW (1.38%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 2928.57 MW (98.54%), Mode Price = $2.05
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.09
# ---
# Episode 12: Total Reward = -1405837.15, Total Cost = $30161.82
# Grid Usage: 1.93 MW (0.06%), Mode Price = $0.05
# Solar Usage: 41.87 MW (1.30%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3169.45 MW (98.64%), Mode Price = $5.35
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.09
# ---
# Episode 13: Total Reward = -1469041.09, Total Cost = $29217.18
# Grid Usage: 4.80 MW (0.15%), Mode Price = $0.05
# Solar Usage: 40.54 MW (1.30%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3065.14 MW (98.54%), Mode Price = $5.07
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.09
# ---
# Episode 14: Total Reward = -1387703.10, Total Cost = $28921.30
# Grid Usage: 1.58 MW (0.05%), Mode Price = $0.05
# Solar Usage: 38.61 MW (1.27%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3008.76 MW (98.68%), Mode Price = $3.70
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.09
# ---
# Episode 15: Total Reward = -1441185.66, Total Cost = $30107.24
# Grid Usage: 4.72 MW (0.15%), Mode Price = $0.05
# Solar Usage: 35.19 MW (1.09%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3185.01 MW (98.76%), Mode Price = $6.08
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.09
# ---
# Episode 16: Total Reward = -1467739.28, Total Cost = $31103.14
# Grid Usage: 1.32 MW (0.04%), Mode Price = $0.05
# Solar Usage: 38.25 MW (1.17%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3235.59 MW (98.79%), Mode Price = $7.81
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.09
# ---
# Episode 17: Total Reward = -1409177.51, Total Cost = $28846.59
# Grid Usage: 3.25 MW (0.11%), Mode Price = $0.05
# Solar Usage: 41.18 MW (1.36%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 2974.93 MW (98.53%), Mode Price = $3.38
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.09
# ---
# Episode 18: Total Reward = -1480910.90, Total Cost = $30050.23
# Grid Usage: 5.84 MW (0.19%), Mode Price = $0.05
# Solar Usage: 37.63 MW (1.20%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3092.18 MW (98.61%), Mode Price = $4.30
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.09
# ---
# Episode 19: Total Reward = -1488141.72, Total Cost = $29849.51
# Grid Usage: 1.23 MW (0.04%), Mode Price = $0.05
# Solar Usage: 43.06 MW (1.34%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3165.12 MW (98.62%), Mode Price = $6.10
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.09
# ---
# Episode 20: Total Reward = -1537330.86, Total Cost = $32619.93
# Grid Usage: 2.20 MW (0.06%), Mode Price = $0.05
# Solar Usage: 38.52 MW (1.12%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3384.79 MW (98.81%), Mode Price = $4.74
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.09
# ---
# Episode 21: Total Reward = -1384015.99, Total Cost = $28753.44
# Grid Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Solar Usage: 36.48 MW (1.19%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3033.27 MW (98.81%), Mode Price = $3.55
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.09
# ---
# Episode 22: Total Reward = -1524947.57, Total Cost = $30900.29
# Grid Usage: 5.32 MW (0.17%), Mode Price = $0.05
# Solar Usage: 39.16 MW (1.23%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3149.07 MW (98.61%), Mode Price = $4.20
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.09
# ---
# Episode 23: Total Reward = -1364717.91, Total Cost = $28711.11
# Grid Usage: 4.41 MW (0.15%), Mode Price = $0.05
# Solar Usage: 36.45 MW (1.21%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 2966.30 MW (98.64%), Mode Price = $3.48
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.09
# ---
# Episode 24: Total Reward = -1595538.39, Total Cost = $32405.37
# Grid Usage: 3.10 MW (0.09%), Mode Price = $0.05
# Solar Usage: 38.31 MW (1.11%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3405.44 MW (98.80%), Mode Price = $7.67
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.09
# ---
# Episode 25: Total Reward = -1485636.77, Total Cost = $29657.59
# Grid Usage: 2.31 MW (0.07%), Mode Price = $0.05
# Solar Usage: 42.21 MW (1.32%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3141.21 MW (98.60%), Mode Price = $6.21
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.09
# ---
# Episode 26: Total Reward = -1403821.16, Total Cost = $29083.58
# Grid Usage: 2.62 MW (0.08%), Mode Price = $0.05
# Solar Usage: 36.55 MW (1.17%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3084.12 MW (98.75%), Mode Price = $7.22
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.09
# ---
# Episode 27: Total Reward = -1410843.49, Total Cost = $28682.50
# Grid Usage: 2.46 MW (0.08%), Mode Price = $0.05
# Solar Usage: 42.78 MW (1.39%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3032.53 MW (98.53%), Mode Price = $3.17
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.09
# ---
# Episode 28: Total Reward = -1666603.69, Total Cost = $32408.24
# Grid Usage: 4.94 MW (0.15%), Mode Price = $0.05
# Solar Usage: 37.18 MW (1.12%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3291.13 MW (98.74%), Mode Price = $4.44
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.09
# ---
# Episode 29: Total Reward = -1353049.78, Total Cost = $30232.73
# Grid Usage: 1.12 MW (0.03%), Mode Price = $0.05
# Solar Usage: 42.05 MW (1.31%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3154.65 MW (98.65%), Mode Price = $7.36
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.09
# ---
# Episode 30: Total Reward = -1438650.68, Total Cost = $28941.82
# Grid Usage: 1.30 MW (0.04%), Mode Price = $0.05
# Solar Usage: 40.10 MW (1.30%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3038.94 MW (98.66%), Mode Price = $2.74
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.09
# ---
# Episode 31: Total Reward = -1396133.47, Total Cost = $28700.00
# Grid Usage: 1.88 MW (0.06%), Mode Price = $0.05
# Solar Usage: 42.22 MW (1.41%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 2945.45 MW (98.52%), Mode Price = $1.80
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.09
# ---
# Episode 32: Total Reward = -1440510.81, Total Cost = $29790.10
# Grid Usage: 4.83 MW (0.15%), Mode Price = $0.05
# Solar Usage: 36.20 MW (1.16%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3085.29 MW (98.69%), Mode Price = $2.79
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.09
# ---
# Episode 33: Total Reward = -1385677.79, Total Cost = $29587.59
# Grid Usage: 3.31 MW (0.11%), Mode Price = $0.05
# Solar Usage: 36.68 MW (1.18%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3066.36 MW (98.71%), Mode Price = $3.86
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.08
# ---
# Episode 34: Total Reward = -1459252.87, Total Cost = $30454.98
# Grid Usage: 6.15 MW (0.19%), Mode Price = $0.05
# Solar Usage: 40.76 MW (1.26%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3189.25 MW (98.55%), Mode Price = $5.03
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.08
# ---
# Episode 35: Total Reward = -1426581.28, Total Cost = $30554.08
# Grid Usage: 3.84 MW (0.12%), Mode Price = $0.05
# Solar Usage: 37.83 MW (1.17%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3183.73 MW (98.71%), Mode Price = $4.69
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.08
# ---
# Episode 36: Total Reward = -1400898.95, Total Cost = $30049.09
# Grid Usage: 1.25 MW (0.04%), Mode Price = $0.05
# Solar Usage: 41.61 MW (1.29%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3171.67 MW (98.67%), Mode Price = $4.89
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.08
# ---
# Episode 37: Total Reward = -1384341.33, Total Cost = $28404.91
# Grid Usage: 3.24 MW (0.11%), Mode Price = $0.05
# Solar Usage: 39.57 MW (1.35%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 2891.43 MW (98.54%), Mode Price = $1.79
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.08
# ---
# Episode 38: Total Reward = -1481531.26, Total Cost = $30099.07
# Grid Usage: 3.37 MW (0.11%), Mode Price = $0.05
# Solar Usage: 42.86 MW (1.35%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3134.24 MW (98.55%), Mode Price = $4.53
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.08
# ---
# Episode 39: Total Reward = -1329975.05, Total Cost = $28251.22
# Grid Usage: 2.79 MW (0.09%), Mode Price = $0.05
# Solar Usage: 38.84 MW (1.28%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 2993.19 MW (98.63%), Mode Price = $3.02
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.08
# ---
# Episode 40: Total Reward = -1486410.36, Total Cost = $30397.01
# Grid Usage: 1.56 MW (0.05%), Mode Price = $0.05
# Solar Usage: 41.72 MW (1.28%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3222.35 MW (98.67%), Mode Price = $5.11
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.08
# ---
# Episode 41: Total Reward = -1285634.23, Total Cost = $26901.32
# Grid Usage: 5.09 MW (0.18%), Mode Price = $0.05
# Solar Usage: 38.76 MW (1.35%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 2819.47 MW (98.47%), Mode Price = $3.63
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.08
# ---
# Episode 42: Total Reward = -1363808.66, Total Cost = $28282.11
# Grid Usage: 1.41 MW (0.05%), Mode Price = $0.05
# Solar Usage: 37.78 MW (1.26%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 2959.80 MW (98.69%), Mode Price = $1.83
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.08
# ---
# Episode 43: Total Reward = -1440398.49, Total Cost = $29468.02
# Grid Usage: 12.52 MW (0.41%), Mode Price = $0.05
# Solar Usage: 42.19 MW (1.38%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3010.64 MW (98.22%), Mode Price = $5.30
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.08
# ---
# Episode 44: Total Reward = -1546151.55, Total Cost = $32351.16
# Grid Usage: 3.72 MW (0.11%), Mode Price = $0.05
# Solar Usage: 41.18 MW (1.23%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3311.08 MW (98.66%), Mode Price = $5.98
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.08
# ---
# Episode 45: Total Reward = -1335813.46, Total Cost = $27960.54
# Grid Usage: 2.20 MW (0.07%), Mode Price = $0.05
# Solar Usage: 39.13 MW (1.31%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 2942.20 MW (98.61%), Mode Price = $2.62
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.08
# ---
# Episode 46: Total Reward = -1427385.94, Total Cost = $29408.92
# Grid Usage: 5.20 MW (0.17%), Mode Price = $0.05
# Solar Usage: 40.01 MW (1.30%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3030.44 MW (98.53%), Mode Price = $4.91
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.08
# ---
# Episode 47: Total Reward = -1522845.09, Total Cost = $29678.21
# Grid Usage: 1.41 MW (0.04%), Mode Price = $0.05
# Solar Usage: 41.14 MW (1.30%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3125.53 MW (98.66%), Mode Price = $4.63
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.08
# ---
# Episode 48: Total Reward = -1450331.45, Total Cost = $30523.31
# Grid Usage: 4.03 MW (0.12%), Mode Price = $0.05
# Solar Usage: 40.93 MW (1.27%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3185.74 MW (98.61%), Mode Price = $3.99
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.08
# ---
# Episode 49: Total Reward = -1376097.75, Total Cost = $28762.41
# Grid Usage: 3.35 MW (0.11%), Mode Price = $0.05
# Solar Usage: 40.73 MW (1.35%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 2971.66 MW (98.54%), Mode Price = $2.62
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.08
# ---
# Episode 50: Total Reward = -1505867.48, Total Cost = $30918.28
# Grid Usage: 3.31 MW (0.10%), Mode Price = $0.05
# Solar Usage: 41.30 MW (1.25%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3268.62 MW (98.65%), Mode Price = $4.07
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.08
# ---
# Episode 51: Total Reward = -1401037.79, Total Cost = $28911.18
# Grid Usage: 2.22 MW (0.07%), Mode Price = $0.05
# Solar Usage: 37.79 MW (1.24%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3007.94 MW (98.69%), Mode Price = $2.08
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.08
# ---
# Episode 52: Total Reward = -1538743.23, Total Cost = $31353.08
# Grid Usage: 7.51 MW (0.22%), Mode Price = $0.05
# Solar Usage: 42.55 MW (1.27%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3301.66 MW (98.51%), Mode Price = $6.59
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.08
# ---
# Episode 53: Total Reward = -1321324.41, Total Cost = $27590.49
# Grid Usage: 5.71 MW (0.19%), Mode Price = $0.05
# Solar Usage: 38.84 MW (1.31%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 2914.74 MW (98.49%), Mode Price = $2.33
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.08
# ---
# Episode 54: Total Reward = -1428186.03, Total Cost = $29112.62
# Grid Usage: 4.48 MW (0.15%), Mode Price = $0.05
# Solar Usage: 42.79 MW (1.41%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 2984.94 MW (98.44%), Mode Price = $3.00
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.08
# ---
# Episode 55: Total Reward = -1305596.82, Total Cost = $28469.71
# Grid Usage: 2.46 MW (0.08%), Mode Price = $0.05
# Solar Usage: 41.62 MW (1.38%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 2980.86 MW (98.54%), Mode Price = $3.73
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.08
# ---
# Episode 56: Total Reward = -1398509.26, Total Cost = $29252.89
# Grid Usage: 6.02 MW (0.19%), Mode Price = $0.05
# Solar Usage: 39.37 MW (1.26%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3069.38 MW (98.54%), Mode Price = $3.27
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.08
# ---
# Episode 57: Total Reward = -1367451.65, Total Cost = $28596.68
# Grid Usage: 5.37 MW (0.18%), Mode Price = $0.05
# Solar Usage: 39.28 MW (1.31%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 2942.38 MW (98.51%), Mode Price = $5.79
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.08
# ---
# Episode 58: Total Reward = -1524225.90, Total Cost = $32112.96
# Grid Usage: 3.66 MW (0.11%), Mode Price = $0.05
# Solar Usage: 42.52 MW (1.28%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3280.43 MW (98.61%), Mode Price = $6.36
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.07
# ---
# Episode 59: Total Reward = -1487375.42, Total Cost = $30620.72
# Grid Usage: 2.95 MW (0.09%), Mode Price = $0.05
# Solar Usage: 42.76 MW (1.32%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3201.28 MW (98.59%), Mode Price = $5.38
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.07
# ---
# Episode 60: Total Reward = -1345585.95, Total Cost = $28319.98
# Grid Usage: 4.20 MW (0.14%), Mode Price = $0.05
# Solar Usage: 35.56 MW (1.17%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 2991.65 MW (98.69%), Mode Price = $4.66
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.07
# ---
# Episode 61: Total Reward = -1343215.29, Total Cost = $27899.43
# Grid Usage: 2.47 MW (0.08%), Mode Price = $0.05
# Solar Usage: 35.95 MW (1.22%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 2906.32 MW (98.70%), Mode Price = $2.42
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.07
# ---
# Episode 62: Total Reward = -1352802.06, Total Cost = $28227.44
# Grid Usage: 3.57 MW (0.12%), Mode Price = $0.05
# Solar Usage: 37.97 MW (1.25%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 2985.87 MW (98.63%), Mode Price = $4.32
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.07
# ---
# Episode 63: Total Reward = -1462298.43, Total Cost = $30001.95
# Grid Usage: 1.51 MW (0.05%), Mode Price = $0.05
# Solar Usage: 42.95 MW (1.34%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3149.74 MW (98.61%), Mode Price = $3.53
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.07
# ---
# Episode 64: Total Reward = -1512095.80, Total Cost = $30395.80
# Grid Usage: 3.87 MW (0.12%), Mode Price = $0.05
# Solar Usage: 41.15 MW (1.27%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3192.14 MW (98.61%), Mode Price = $6.45
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.07
# ---
# Episode 65: Total Reward = -1473256.32, Total Cost = $29117.34
# Grid Usage: 6.07 MW (0.19%), Mode Price = $0.05
# Solar Usage: 37.69 MW (1.21%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3078.36 MW (98.60%), Mode Price = $4.49
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.07
# ---
# Episode 66: Total Reward = -1302674.29, Total Cost = $27418.80
# Grid Usage: 3.13 MW (0.11%), Mode Price = $0.05
# Solar Usage: 44.09 MW (1.49%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 2904.23 MW (98.40%), Mode Price = $3.48
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.07
# ---
# Episode 67: Total Reward = -1412702.71, Total Cost = $29056.30
# Grid Usage: 1.66 MW (0.05%), Mode Price = $0.05
# Solar Usage: 40.14 MW (1.29%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3066.82 MW (98.66%), Mode Price = $3.51
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.07
# ---
# Episode 68: Total Reward = -1455758.79, Total Cost = $30233.43
# Grid Usage: 6.17 MW (0.19%), Mode Price = $0.05
# Solar Usage: 40.69 MW (1.26%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3173.38 MW (98.54%), Mode Price = $5.85
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.07
# ---
# Episode 69: Total Reward = -1417273.34, Total Cost = $29307.10
# Grid Usage: 3.60 MW (0.12%), Mode Price = $0.05
# Solar Usage: 35.56 MW (1.14%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3083.97 MW (98.75%), Mode Price = $3.13
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.07
# ---
# Episode 70: Total Reward = -1296265.73, Total Cost = $27436.36
# Grid Usage: 5.88 MW (0.20%), Mode Price = $0.05
# Solar Usage: 37.49 MW (1.28%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 2892.78 MW (98.52%), Mode Price = $2.62
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.07
# ---
# Episode 71: Total Reward = -1396846.52, Total Cost = $29245.16
# Grid Usage: 0.63 MW (0.02%), Mode Price = $0.05
# Solar Usage: 39.91 MW (1.25%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3141.93 MW (98.73%), Mode Price = $4.74
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.07
# ---
# Episode 72: Total Reward = -1445541.05, Total Cost = $29760.02
# Grid Usage: 5.14 MW (0.16%), Mode Price = $0.05
# Solar Usage: 39.25 MW (1.24%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3113.59 MW (98.59%), Mode Price = $3.80
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.07
# ---
# Episode 73: Total Reward = -1436485.21, Total Cost = $30225.17
# Grid Usage: 4.34 MW (0.14%), Mode Price = $0.05
# Solar Usage: 37.65 MW (1.18%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3160.02 MW (98.69%), Mode Price = $6.33
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.07
# ---
# Episode 74: Total Reward = -1497619.73, Total Cost = $31134.80
# Grid Usage: 3.35 MW (0.10%), Mode Price = $0.05
# Solar Usage: 42.24 MW (1.30%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3213.15 MW (98.60%), Mode Price = $4.48
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.07
# ---
# Episode 75: Total Reward = -1406233.78, Total Cost = $28724.27
# Grid Usage: 1.85 MW (0.06%), Mode Price = $0.05
# Solar Usage: 42.89 MW (1.35%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3122.71 MW (98.59%), Mode Price = $4.05
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.07
# ---
# Episode 76: Total Reward = -1575390.49, Total Cost = $33080.09
# Grid Usage: 3.45 MW (0.10%), Mode Price = $0.05
# Solar Usage: 40.80 MW (1.19%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3386.14 MW (98.71%), Mode Price = $6.82
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.07
# ---
# Episode 77: Total Reward = -1555192.35, Total Cost = $32083.59
# Grid Usage: 3.05 MW (0.09%), Mode Price = $0.05
# Solar Usage: 44.03 MW (1.32%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3282.09 MW (98.59%), Mode Price = $4.82
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.07
# ---
# Episode 78: Total Reward = -1391903.05, Total Cost = $30124.27
# Grid Usage: 2.83 MW (0.09%), Mode Price = $0.05
# Solar Usage: 35.67 MW (1.13%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3120.99 MW (98.78%), Mode Price = $3.92
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.07
# ---
# Episode 79: Total Reward = -1414472.42, Total Cost = $28321.89
# Grid Usage: 3.54 MW (0.12%), Mode Price = $0.05
# Solar Usage: 34.05 MW (1.13%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 2987.87 MW (98.76%), Mode Price = $4.04
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.07
# ---
# Episode 80: Total Reward = -1460692.95, Total Cost = $28877.61
# Grid Usage: 5.78 MW (0.19%), Mode Price = $0.05
# Solar Usage: 38.64 MW (1.24%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3072.74 MW (98.58%), Mode Price = $4.15
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.07
# ---
# Episode 81: Total Reward = -1408051.43, Total Cost = $28149.67
# Grid Usage: 3.89 MW (0.13%), Mode Price = $0.05
# Solar Usage: 42.83 MW (1.43%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 2938.63 MW (98.44%), Mode Price = $1.75
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.07
# ---
# Episode 82: Total Reward = -1591132.21, Total Cost = $31967.34
# Grid Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Solar Usage: 39.44 MW (1.18%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3297.88 MW (98.82%), Mode Price = $5.29
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.07
# ---
# Episode 83: Total Reward = -1522534.42, Total Cost = $29909.05
# Grid Usage: 4.32 MW (0.14%), Mode Price = $0.05
# Solar Usage: 39.38 MW (1.25%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3097.73 MW (98.61%), Mode Price = $4.58
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.07
# ---
# Episode 84: Total Reward = -1441108.89, Total Cost = $30039.80
# Grid Usage: 2.30 MW (0.07%), Mode Price = $0.05
# Solar Usage: 43.09 MW (1.38%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3079.25 MW (98.55%), Mode Price = $3.39
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.07
# ---
# Episode 85: Total Reward = -1490456.89, Total Cost = $30250.28
# Grid Usage: 0.66 MW (0.02%), Mode Price = $0.05
# Solar Usage: 45.71 MW (1.41%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3186.59 MW (98.57%), Mode Price = $4.84
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.07
# ---
# Episode 86: Total Reward = -1556310.34, Total Cost = $31317.99
# Grid Usage: 4.12 MW (0.13%), Mode Price = $0.05
# Solar Usage: 33.05 MW (1.00%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3259.93 MW (98.87%), Mode Price = $5.24
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.06
# ---
# Episode 87: Total Reward = -1393656.26, Total Cost = $29277.15
# Grid Usage: 2.88 MW (0.09%), Mode Price = $0.05
# Solar Usage: 38.28 MW (1.22%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3109.28 MW (98.69%), Mode Price = $3.89
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.06
# ---
# Episode 88: Total Reward = -1432830.13, Total Cost = $29968.84
# Grid Usage: 4.59 MW (0.14%), Mode Price = $0.05
# Solar Usage: 39.77 MW (1.23%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3180.29 MW (98.62%), Mode Price = $4.16
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.06
# ---
# Episode 89: Total Reward = -1461273.11, Total Cost = $30154.19
# Grid Usage: 3.86 MW (0.12%), Mode Price = $0.05
# Solar Usage: 38.35 MW (1.19%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3167.34 MW (98.69%), Mode Price = $3.80
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.06
# ---
# Episode 90: Total Reward = -1450856.43, Total Cost = $29629.08
# Grid Usage: 3.39 MW (0.11%), Mode Price = $0.05
# Solar Usage: 36.19 MW (1.18%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3024.78 MW (98.71%), Mode Price = $5.09
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.06
# ---
# Episode 91: Total Reward = -1486078.99, Total Cost = $30827.52
# Grid Usage: 0.62 MW (0.02%), Mode Price = $0.05
# Solar Usage: 40.21 MW (1.23%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3234.14 MW (98.75%), Mode Price = $3.62
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.06
# ---
# Episode 92: Total Reward = -1383137.55, Total Cost = $27959.69
# Grid Usage: 6.83 MW (0.23%), Mode Price = $0.05
# Solar Usage: 39.49 MW (1.33%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 2914.41 MW (98.44%), Mode Price = $3.23
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.06
# ---
# Episode 93: Total Reward = -1313291.42, Total Cost = $26997.42
# Grid Usage: 3.15 MW (0.11%), Mode Price = $0.05
# Solar Usage: 40.07 MW (1.36%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 2897.73 MW (98.53%), Mode Price = $3.08
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.06
# ---
# Episode 94: Total Reward = -1411940.92, Total Cost = $30034.24
# Grid Usage: 3.36 MW (0.11%), Mode Price = $0.05
# Solar Usage: 44.76 MW (1.43%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3089.50 MW (98.47%), Mode Price = $4.53
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.06
# ---
# Episode 95: Total Reward = -1427591.79, Total Cost = $30189.34
# Grid Usage: 3.19 MW (0.10%), Mode Price = $0.05
# Solar Usage: 40.89 MW (1.30%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3104.23 MW (98.60%), Mode Price = $4.60
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.06
# ---
# Episode 96: Total Reward = -1421939.91, Total Cost = $29035.85
# Grid Usage: 1.37 MW (0.04%), Mode Price = $0.05
# Solar Usage: 40.85 MW (1.33%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3018.30 MW (98.62%), Mode Price = $4.54
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.06
# ---
# Episode 97: Total Reward = -1450966.76, Total Cost = $29984.80
# Grid Usage: 2.77 MW (0.09%), Mode Price = $0.05
# Solar Usage: 41.21 MW (1.33%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3063.84 MW (98.59%), Mode Price = $3.43
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.06
# ---
# Episode 98: Total Reward = -1508556.29, Total Cost = $31532.79
# Grid Usage: 0.45 MW (0.01%), Mode Price = $0.05
# Solar Usage: 38.70 MW (1.20%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3196.77 MW (98.79%), Mode Price = $4.95
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.06
# ---
# Episode 99: Total Reward = -1376926.05, Total Cost = $28278.42
# Grid Usage: 6.61 MW (0.22%), Mode Price = $0.05
# Solar Usage: 40.21 MW (1.33%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 2969.54 MW (98.45%), Mode Price = $4.67
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.06
# ---
# Episode 100: Total Reward = -1442785.53, Total Cost = $29286.27
# Grid Usage: 5.18 MW (0.16%), Mode Price = $0.05
# Solar Usage: 40.82 MW (1.30%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3102.17 MW (98.54%), Mode Price = $4.23
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.06
# ---
# Episode 101: Total Reward = -1300396.30, Total Cost = $27923.77
# Grid Usage: 3.84 MW (0.13%), Mode Price = $0.05
# Solar Usage: 42.96 MW (1.45%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 2924.98 MW (98.43%), Mode Price = $3.75
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.06
# ---
# Episode 102: Total Reward = -1454827.41, Total Cost = $29201.31
# Grid Usage: 5.56 MW (0.18%), Mode Price = $0.05
# Solar Usage: 38.87 MW (1.23%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3103.69 MW (98.59%), Mode Price = $3.58
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.06
# ---
# Episode 103: Total Reward = -1431422.13, Total Cost = $29499.33
# Grid Usage: 0.42 MW (0.01%), Mode Price = $0.05
# Solar Usage: 43.57 MW (1.40%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3061.09 MW (98.58%), Mode Price = $5.21
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.06
# ---
# Episode 104: Total Reward = -1538499.56, Total Cost = $31499.65
# Grid Usage: 2.74 MW (0.08%), Mode Price = $0.05
# Solar Usage: 40.48 MW (1.23%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3240.47 MW (98.68%), Mode Price = $4.62
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.06
# ---
# Episode 105: Total Reward = -1605163.11, Total Cost = $32737.92
# Grid Usage: 1.62 MW (0.05%), Mode Price = $0.05
# Solar Usage: 41.42 MW (1.19%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3426.57 MW (98.76%), Mode Price = $5.26
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.06
# ---
# Episode 106: Total Reward = -1473817.37, Total Cost = $30448.99
# Grid Usage: 1.11 MW (0.03%), Mode Price = $0.05
# Solar Usage: 36.13 MW (1.14%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3143.07 MW (98.83%), Mode Price = $5.39
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.06
# ---
# Episode 107: Total Reward = -1513345.69, Total Cost = $31004.63
# Grid Usage: 1.53 MW (0.05%), Mode Price = $0.05
# Solar Usage: 40.84 MW (1.25%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3234.53 MW (98.71%), Mode Price = $4.90
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.06
# ---
# Episode 108: Total Reward = -1400695.62, Total Cost = $29545.17
# Grid Usage: 3.36 MW (0.11%), Mode Price = $0.05
# Solar Usage: 42.07 MW (1.35%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3077.29 MW (98.55%), Mode Price = $3.75
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.06
# ---
# Episode 109: Total Reward = -1310793.84, Total Cost = $27984.22
# Grid Usage: 5.05 MW (0.17%), Mode Price = $0.05
# Solar Usage: 40.57 MW (1.39%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 2864.51 MW (98.43%), Mode Price = $1.95
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.06
# ---
# Episode 110: Total Reward = -1401139.46, Total Cost = $29199.02
# Grid Usage: 3.49 MW (0.11%), Mode Price = $0.05
# Solar Usage: 39.09 MW (1.26%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3047.81 MW (98.62%), Mode Price = $3.68
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.06
# ---
# Episode 111: Total Reward = -1320029.72, Total Cost = $27879.18
# Grid Usage: 2.99 MW (0.10%), Mode Price = $0.05
# Solar Usage: 40.45 MW (1.37%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 2911.09 MW (98.53%), Mode Price = $3.00
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.06
# ---
# Episode 112: Total Reward = -1432963.02, Total Cost = $29483.91
# Grid Usage: 3.59 MW (0.12%), Mode Price = $0.05
# Solar Usage: 43.85 MW (1.42%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3031.42 MW (98.46%), Mode Price = $4.95
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.06
# ---
# Episode 113: Total Reward = -1389180.40, Total Cost = $28441.08
# Grid Usage: 6.16 MW (0.20%), Mode Price = $0.05
# Solar Usage: 39.87 MW (1.32%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 2981.92 MW (98.48%), Mode Price = $3.06
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.06
# ---
# Episode 114: Total Reward = -1389424.82, Total Cost = $29005.50
# Grid Usage: 6.45 MW (0.21%), Mode Price = $0.05
# Solar Usage: 44.49 MW (1.43%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3062.09 MW (98.36%), Mode Price = $6.03
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.06
# ---
# Episode 115: Total Reward = -1468708.32, Total Cost = $31361.84
# Grid Usage: 0.09 MW (0.00%), Mode Price = $0.05
# Solar Usage: 40.98 MW (1.25%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3230.74 MW (98.74%), Mode Price = $3.75
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.06
# ---
# Episode 116: Total Reward = -1493337.05, Total Cost = $29709.29
# Grid Usage: 4.12 MW (0.13%), Mode Price = $0.05
# Solar Usage: 39.99 MW (1.24%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3189.33 MW (98.64%), Mode Price = $6.36
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.06
# ---
# Episode 117: Total Reward = -1352322.13, Total Cost = $28416.26
# Grid Usage: 2.09 MW (0.07%), Mode Price = $0.05
# Solar Usage: 37.24 MW (1.25%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 2944.15 MW (98.68%), Mode Price = $3.65
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.06
# ---
# Episode 118: Total Reward = -1407763.25, Total Cost = $29173.85
# Grid Usage: 2.31 MW (0.07%), Mode Price = $0.05
# Solar Usage: 38.97 MW (1.26%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3058.13 MW (98.67%), Mode Price = $3.48
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.06
# ---
# Episode 119: Total Reward = -1416392.52, Total Cost = $29760.90
# Grid Usage: 2.07 MW (0.07%), Mode Price = $0.05
# Solar Usage: 39.75 MW (1.27%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3079.75 MW (98.66%), Mode Price = $4.71
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.06
# ---
# Episode 120: Total Reward = -1645098.74, Total Cost = $31733.74
# Grid Usage: 3.97 MW (0.12%), Mode Price = $0.05
# Solar Usage: 42.13 MW (1.27%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3282.58 MW (98.62%), Mode Price = $5.71
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.05
# ---
# Episode 121: Total Reward = -1561463.95, Total Cost = $32643.86
# Grid Usage: 3.01 MW (0.09%), Mode Price = $0.05
# Solar Usage: 41.27 MW (1.20%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3402.42 MW (98.72%), Mode Price = $5.81
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.05
# ---
# Episode 122: Total Reward = -1447149.39, Total Cost = $28680.59
# Grid Usage: 4.93 MW (0.16%), Mode Price = $0.05
# Solar Usage: 42.92 MW (1.39%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3039.74 MW (98.45%), Mode Price = $6.88
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.05
# ---
# Episode 123: Total Reward = -1538275.34, Total Cost = $33215.83
# Grid Usage: 5.63 MW (0.16%), Mode Price = $0.05
# Solar Usage: 39.81 MW (1.12%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3496.07 MW (98.72%), Mode Price = $5.39
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.05
# ---
# Episode 124: Total Reward = -1410589.91, Total Cost = $29246.67
# Grid Usage: 3.59 MW (0.12%), Mode Price = $0.05
# Solar Usage: 34.18 MW (1.09%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3084.55 MW (98.79%), Mode Price = $3.98
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.05
# ---
# Episode 125: Total Reward = -1446120.83, Total Cost = $30927.24
# Grid Usage: 4.26 MW (0.13%), Mode Price = $0.05
# Solar Usage: 43.55 MW (1.36%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3161.29 MW (98.51%), Mode Price = $5.44
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.05
# ---
# Episode 126: Total Reward = -1604039.11, Total Cost = $32784.92
# Grid Usage: 0.81 MW (0.02%), Mode Price = $0.05
# Solar Usage: 39.12 MW (1.12%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3452.59 MW (98.86%), Mode Price = $6.41
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.05
# ---
# Episode 127: Total Reward = -1565909.69, Total Cost = $31431.74
# Grid Usage: 1.96 MW (0.06%), Mode Price = $0.05
# Solar Usage: 39.59 MW (1.20%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3263.06 MW (98.74%), Mode Price = $5.40
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.05
# ---
# Episode 128: Total Reward = -1494759.10, Total Cost = $31525.10
# Grid Usage: 5.79 MW (0.18%), Mode Price = $0.05
# Solar Usage: 39.09 MW (1.19%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3249.91 MW (98.64%), Mode Price = $5.47
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.05
# ---
# Episode 129: Total Reward = -1376105.41, Total Cost = $30035.96
# Grid Usage: 2.37 MW (0.07%), Mode Price = $0.05
# Solar Usage: 43.54 MW (1.37%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3123.20 MW (98.55%), Mode Price = $5.64
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.05
# ---
# Episode 130: Total Reward = -1443173.98, Total Cost = $30004.56
# Grid Usage: 3.80 MW (0.12%), Mode Price = $0.05
# Solar Usage: 38.73 MW (1.24%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3075.04 MW (98.64%), Mode Price = $4.01
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.05
# ---
# Episode 131: Total Reward = -1455469.98, Total Cost = $29534.63
# Grid Usage: 4.96 MW (0.16%), Mode Price = $0.05
# Solar Usage: 39.28 MW (1.25%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3087.15 MW (98.59%), Mode Price = $4.32
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.05
# ---
# Episode 132: Total Reward = -1459664.65, Total Cost = $29879.63
# Grid Usage: 2.91 MW (0.09%), Mode Price = $0.05
# Solar Usage: 33.25 MW (1.05%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3133.78 MW (98.86%), Mode Price = $6.20
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.05
# ---
# Episode 133: Total Reward = -1388069.44, Total Cost = $30313.46
# Grid Usage: 0.33 MW (0.01%), Mode Price = $0.05
# Solar Usage: 42.38 MW (1.34%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3122.69 MW (98.65%), Mode Price = $5.08
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.05
# ---
# Episode 134: Total Reward = -1582179.50, Total Cost = $31617.16
# Grid Usage: 2.82 MW (0.08%), Mode Price = $0.05
# Solar Usage: 36.22 MW (1.09%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3283.68 MW (98.83%), Mode Price = $5.07
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.05
# ---
# Episode 135: Total Reward = -1588013.90, Total Cost = $32072.90
# Grid Usage: 2.86 MW (0.09%), Mode Price = $0.05
# Solar Usage: 40.97 MW (1.23%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3292.73 MW (98.69%), Mode Price = $6.09
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.05
# ---
# Episode 136: Total Reward = -1405050.88, Total Cost = $28990.03
# Grid Usage: 5.74 MW (0.19%), Mode Price = $0.05
# Solar Usage: 37.38 MW (1.23%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3003.26 MW (98.58%), Mode Price = $4.47
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.05
# ---
# Episode 137: Total Reward = -1407253.02, Total Cost = $29037.70
# Grid Usage: 5.84 MW (0.19%), Mode Price = $0.05
# Solar Usage: 38.27 MW (1.24%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# ...
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.00
# ---
# Episode 1956: Total Reward = -1413461.08, Total Cost = $28942.81
# Grid Usage: 4.01 MW (0.13%), Mode Price = $0.05
# Solar Usage: 44.30 MW (1.41%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3094.30 MW (98.46%), Mode Price = $4.21
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.00
# ---
# Episode 1957: Total Reward = -1546887.47, Total Cost = $33043.82
# Grid Usage: 3.23 MW (0.09%), Mode Price = $0.05
# Solar Usage: 41.09 MW (1.20%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3384.97 MW (98.71%), Mode Price = $5.71
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.00
# ---
# Episode 1958: Total Reward = -1412286.19, Total Cost = $29562.42
# Grid Usage: 0.34 MW (0.01%), Mode Price = $0.05
# Solar Usage: 40.10 MW (1.27%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3117.25 MW (98.72%), Mode Price = $2.32
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.00
# ---
# Episode 1959: Total Reward = -1613746.65, Total Cost = $31715.98
# Grid Usage: 5.31 MW (0.16%), Mode Price = $0.05
# Solar Usage: 38.25 MW (1.15%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3282.64 MW (98.69%), Mode Price = $4.32
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.00
# ---
# Episode 1960: Total Reward = -1358139.50, Total Cost = $28580.01
# Grid Usage: 0.88 MW (0.03%), Mode Price = $0.05
# Solar Usage: 38.83 MW (1.26%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3034.61 MW (98.71%), Mode Price = $3.27
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.00
# ---
# Episode 1961: Total Reward = -1408321.78, Total Cost = $29230.99
# Grid Usage: 6.15 MW (0.20%), Mode Price = $0.05
# Solar Usage: 40.05 MW (1.30%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3037.16 MW (98.50%), Mode Price = $2.75
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.00
# ---
# Episode 1962: Total Reward = -1464353.12, Total Cost = $30675.91
# Grid Usage: 3.40 MW (0.11%), Mode Price = $0.05
# Solar Usage: 44.37 MW (1.38%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3174.23 MW (98.52%), Mode Price = $4.43
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.00
# ---
# Episode 1963: Total Reward = -1415786.16, Total Cost = $29389.90
# Grid Usage: 8.33 MW (0.26%), Mode Price = $0.05
# Solar Usage: 39.46 MW (1.24%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3146.06 MW (98.50%), Mode Price = $5.50
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.00
# ---
# Episode 1964: Total Reward = -1434514.55, Total Cost = $29250.37
# Grid Usage: 3.74 MW (0.12%), Mode Price = $0.05
# Solar Usage: 42.04 MW (1.35%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3064.37 MW (98.53%), Mode Price = $4.80
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.00
# ---
# Episode 1965: Total Reward = -1440182.99, Total Cost = $31906.86
# Grid Usage: 1.18 MW (0.04%), Mode Price = $0.05
# Solar Usage: 43.44 MW (1.31%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3265.21 MW (98.65%), Mode Price = $6.10
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.00
# ---
# Episode 1966: Total Reward = -1527695.70, Total Cost = $30437.93
# Grid Usage: 4.85 MW (0.15%), Mode Price = $0.05
# Solar Usage: 40.00 MW (1.26%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3129.46 MW (98.59%), Mode Price = $5.79
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.00
# ---
# Episode 1967: Total Reward = -1502420.72, Total Cost = $30912.58
# Grid Usage: 2.23 MW (0.07%), Mode Price = $0.05
# Solar Usage: 39.57 MW (1.23%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3176.48 MW (98.70%), Mode Price = $5.26
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.00
# ---
# Episode 1968: Total Reward = -1545194.96, Total Cost = $30543.28
# Grid Usage: 1.52 MW (0.05%), Mode Price = $0.05
# Solar Usage: 38.21 MW (1.17%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3235.06 MW (98.79%), Mode Price = $5.92
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.00
# ---
# Episode 1969: Total Reward = -1419777.62, Total Cost = $29411.19
# Grid Usage: 7.27 MW (0.24%), Mode Price = $0.05
# Solar Usage: 40.84 MW (1.32%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3043.96 MW (98.44%), Mode Price = $4.56
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.00
# ---
# Episode 1970: Total Reward = -1479684.29, Total Cost = $31608.94
# Grid Usage: 1.89 MW (0.06%), Mode Price = $0.05
# Solar Usage: 41.06 MW (1.23%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3297.75 MW (98.71%), Mode Price = $5.34
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.00
# ---
# Episode 1971: Total Reward = -1383450.07, Total Cost = $29371.08
# Grid Usage: 2.55 MW (0.08%), Mode Price = $0.05
# Solar Usage: 37.55 MW (1.19%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3124.58 MW (98.73%), Mode Price = $6.96
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.00
# ---
# Episode 1972: Total Reward = -1357041.71, Total Cost = $28547.44
# Grid Usage: 2.63 MW (0.09%), Mode Price = $0.05
# Solar Usage: 37.54 MW (1.22%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3029.14 MW (98.69%), Mode Price = $4.61
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.00
# ---
# Episode 1973: Total Reward = -1476949.47, Total Cost = $31542.39
# Grid Usage: 2.56 MW (0.08%), Mode Price = $0.05
# Solar Usage: 39.47 MW (1.16%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3345.74 MW (98.76%), Mode Price = $5.34
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.00
# ---
# Episode 1974: Total Reward = -1390843.79, Total Cost = $28614.22
# Grid Usage: 6.40 MW (0.21%), Mode Price = $0.05
# Solar Usage: 45.59 MW (1.52%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 2945.87 MW (98.27%), Mode Price = $1.95
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.00
# ---
# Episode 1975: Total Reward = -1422511.00, Total Cost = $30082.50
# Grid Usage: 1.29 MW (0.04%), Mode Price = $0.05
# Solar Usage: 38.99 MW (1.23%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3130.03 MW (98.73%), Mode Price = $3.86
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.00
# ---
# Episode 1976: Total Reward = -1401131.56, Total Cost = $28651.36
# Grid Usage: 6.02 MW (0.20%), Mode Price = $0.05
# Solar Usage: 41.54 MW (1.40%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 2925.95 MW (98.40%), Mode Price = $2.53
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.00
# ---
# Episode 1977: Total Reward = -1625309.80, Total Cost = $32941.66
# Grid Usage: 1.98 MW (0.06%), Mode Price = $0.05
# Solar Usage: 37.73 MW (1.07%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3483.94 MW (98.87%), Mode Price = $6.21
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.00
# ---
# Episode 1978: Total Reward = -1483368.40, Total Cost = $29740.34
# Grid Usage: 2.29 MW (0.07%), Mode Price = $0.05
# Solar Usage: 39.67 MW (1.27%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3082.84 MW (98.66%), Mode Price = $5.01
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.00
# ---
# Episode 1979: Total Reward = -1528563.39, Total Cost = $30903.59
# Grid Usage: 4.17 MW (0.13%), Mode Price = $0.05
# Solar Usage: 38.17 MW (1.19%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3171.70 MW (98.68%), Mode Price = $5.11
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.00
# ---
# Episode 1980: Total Reward = -1620707.26, Total Cost = $31116.32
# Grid Usage: 4.55 MW (0.14%), Mode Price = $0.05
# Solar Usage: 39.85 MW (1.20%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3263.58 MW (98.66%), Mode Price = $4.41
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.00
# ---
# Episode 1981: Total Reward = -1406766.91, Total Cost = $29476.06
# Grid Usage: 1.75 MW (0.06%), Mode Price = $0.05
# Solar Usage: 42.23 MW (1.36%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3069.96 MW (98.59%), Mode Price = $3.78
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.00
# ---
# Episode 1982: Total Reward = -1658621.59, Total Cost = $32013.14
# Grid Usage: 3.66 MW (0.11%), Mode Price = $0.05
# Solar Usage: 37.61 MW (1.11%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3353.35 MW (98.78%), Mode Price = $6.73
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.00
# ---
# Episode 1983: Total Reward = -1438607.89, Total Cost = $29477.18
# Grid Usage: 4.15 MW (0.13%), Mode Price = $0.05
# Solar Usage: 41.13 MW (1.30%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3112.29 MW (98.57%), Mode Price = $5.40
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.00
# ---
# Episode 1984: Total Reward = -1586388.97, Total Cost = $30716.49
# Grid Usage: 4.90 MW (0.15%), Mode Price = $0.05
# Solar Usage: 36.94 MW (1.13%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3213.69 MW (98.71%), Mode Price = $5.31
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.00
# ---
# Episode 1985: Total Reward = -1397852.82, Total Cost = $28073.22
# Grid Usage: 2.63 MW (0.09%), Mode Price = $0.05
# Solar Usage: 42.64 MW (1.47%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 2859.44 MW (98.44%), Mode Price = $2.64
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.00
# ---
# Episode 1986: Total Reward = -1378731.87, Total Cost = $29050.66
# Grid Usage: 1.44 MW (0.05%), Mode Price = $0.05
# Solar Usage: 45.04 MW (1.43%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3111.54 MW (98.53%), Mode Price = $3.14
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.00
# ---
# Episode 1987: Total Reward = -1415553.48, Total Cost = $29046.05
# Grid Usage: 3.48 MW (0.11%), Mode Price = $0.05
# Solar Usage: 38.53 MW (1.25%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3027.91 MW (98.63%), Mode Price = $6.68
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.00
# ---
# Episode 1988: Total Reward = -1367579.03, Total Cost = $28842.39
# Grid Usage: 4.48 MW (0.15%), Mode Price = $0.05
# Solar Usage: 34.55 MW (1.14%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 2994.11 MW (98.71%), Mode Price = $3.48
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.00
# ---
# Episode 1989: Total Reward = -1427088.61, Total Cost = $29243.25
# Grid Usage: 4.25 MW (0.14%), Mode Price = $0.05
# Solar Usage: 42.57 MW (1.40%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3000.10 MW (98.46%), Mode Price = $3.16
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.00
# ---
# Episode 1990: Total Reward = -1447219.08, Total Cost = $29736.95
# Grid Usage: 3.02 MW (0.10%), Mode Price = $0.05
# Solar Usage: 38.93 MW (1.24%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3103.22 MW (98.67%), Mode Price = $3.87
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.00
# ---
# Episode 1991: Total Reward = -1480633.47, Total Cost = $30105.58
# Grid Usage: 8.36 MW (0.26%), Mode Price = $0.05
# Solar Usage: 38.85 MW (1.21%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3176.26 MW (98.54%), Mode Price = $5.10
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.00
# ---
# Episode 1992: Total Reward = -1471279.09, Total Cost = $30874.67
# Grid Usage: 1.58 MW (0.05%), Mode Price = $0.05
# Solar Usage: 43.00 MW (1.35%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3146.70 MW (98.60%), Mode Price = $8.41
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.00
# ---
# Episode 1993: Total Reward = -1398450.80, Total Cost = $29253.55
# Grid Usage: 3.41 MW (0.11%), Mode Price = $0.05
# Solar Usage: 40.52 MW (1.29%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3098.00 MW (98.60%), Mode Price = $3.48
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.00
# ---
# Episode 1994: Total Reward = -1376611.61, Total Cost = $29012.53
# Grid Usage: 1.72 MW (0.06%), Mode Price = $0.05
# Solar Usage: 45.48 MW (1.47%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3045.26 MW (98.47%), Mode Price = $3.47
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.00
# ---
# Episode 1995: Total Reward = -1397631.14, Total Cost = $29360.64
# Grid Usage: 6.10 MW (0.19%), Mode Price = $0.05
# Solar Usage: 41.66 MW (1.33%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3088.88 MW (98.48%), Mode Price = $4.11
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.00
# ---
# Episode 1996: Total Reward = -1462431.33, Total Cost = $30561.04
# Grid Usage: 5.60 MW (0.17%), Mode Price = $0.05
# Solar Usage: 40.82 MW (1.26%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3188.41 MW (98.56%), Mode Price = $5.54
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.00
# ---
# Episode 1997: Total Reward = -1506432.90, Total Cost = $30864.97
# Grid Usage: 2.86 MW (0.09%), Mode Price = $0.05
# Solar Usage: 41.38 MW (1.30%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3128.06 MW (98.61%), Mode Price = $4.24
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.00
# ---
# Episode 1998: Total Reward = -1446495.04, Total Cost = $30027.63
# Grid Usage: 1.69 MW (0.05%), Mode Price = $0.05
# Solar Usage: 41.72 MW (1.33%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3097.37 MW (98.62%), Mode Price = $3.69
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.00
# ---
# Episode 1999: Total Reward = -1439238.56, Total Cost = $28165.54
# Grid Usage: 5.26 MW (0.18%), Mode Price = $0.05
# Solar Usage: 40.02 MW (1.35%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 2919.39 MW (98.47%), Mode Price = $3.83
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.00
# ---
# Episode 2000: Total Reward = -1550680.82, Total Cost = $31311.20
# Grid Usage: 1.97 MW (0.06%), Mode Price = $0.05
# Solar Usage: 39.01 MW (1.18%), Mode Price = $0.00
# Battery Usage: 0.00 MW (0.00%), Mode Price = $0.00
# Generator Usage: 3270.13 MW (98.76%), Mode Price = $7.56
# Battery Capacity: 200.00 MWh
# Energy Used for Charging: 0.00 MWh
# Epsilon: 0.00
# ---
# Average Total Cost: $30014.67
